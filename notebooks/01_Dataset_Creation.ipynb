# %%
import pandas as pd
import re

# %% [markdown]
# # Loading datasets

# %%
df_fake = pd.read_csv("../dataset/raw/Fake.csv")
df_truth = pd.read_csv("../dataset/raw/True.csv")
df_extra = pd.read_csv("../dataset/raw/extra.csv")

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_truth.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_extra.head() # label 1 is unreliable and 0 is reliable
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %% [markdown]
# # Processing and Merging Datasets

# %% [markdown]
# "(Reuters)" seems like a bias in df_truth, thus should be removed

# %%
# Remove "(Reuters)" Bias from Truth News 
def remove_reuters(text):
    return re.sub(r"\(Reuters\)", "", text).strip()

df_truth["text"] = df_truth["text"].apply(remove_reuters)
df_truth.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON  - The head of a conservative Repub...  politicsNews
# 1  WASHINGTON  - Transgender people will be allow...  politicsNews
# 2  WASHINGTON  - The special counsel investigatio...  politicsNews
# 3  WASHINGTON  - Trump campaign adviser George Pa...  politicsNews
# 4  SEATTLE/WASHINGTON  - President Donald Trump c...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %% [markdown]
# To combine the three datasets, we will only keep important parameters like title, text and author

# %%
df_fake = df_fake[["title", "text"]]
df_truth = df_truth[["title", "text"]]
df_extra = df_extra[["title", "text", "author", "label"]]

# %%
df_fake["unreliable"] = 1
df_fake["author"] = "Unknown"
df_truth["unreliable"] = 0
df_truth["author"] = "Unknown"
df_extra = df_extra.rename(columns={"label":"unreliable"})

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text  unreliable   author
# 0  Donald Trump just couldn t wish all Americans ...           1  Unknown
# 1  House Intelligence Committee Chairman Devin Nu...           1  Unknown
# 2  On Friday, it was revealed that former Milwauk...           1  Unknown
# 3  On Christmas day, Donald Trump announced that ...           1  Unknown
# 4  Pope Francis used his annual Christmas Day mes...           1  Unknown

# %%
df_truth.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text  unreliable   author
# 0  WASHINGTON  - The head of a conservative Repub...           0  Unknown
# 1  WASHINGTON  - Transgender people will be allow...           0  Unknown
# 2  WASHINGTON  - The special counsel investigatio...           0  Unknown
# 3  WASHINGTON  - Trump campaign adviser George Pa...           0  Unknown
# 4  SEATTLE/WASHINGTON  - President Donald Trump c...           0  Unknown

# %%
df_extra.head()
# Out:
#                                                title  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2                  Why the Truth Might Get You Fired
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...
#
#                                                 text              author  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1  Ever get the feeling your life circles the rou...     Daniel J. Flynn
# 2  Why the Truth Might Get You Fired October 29, ...  Consortiumnews.com
# 3  Videos 15 Civilians Killed In Single US Airstr...     Jessica Purkiss
# 4  Print \nAn Iranian woman has been sentenced to...      Howard Portnoy
#
#    unreliable
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
#Merge All Datasets
merged_df = pd.concat([df_fake, df_truth, df_extra], ignore_index=True)
merged_df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 65693  Rapper T.I.: Trump a ’Poster Child For White S...
# 65694  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 65695  Macy’s Is Said to Receive Takeover Approach by...
# 65696  NATO, Russia To Hold Parallel Exercises In Bal...
# 65697                          What Keeps the F-35 Alive
#
#                                                     text  unreliable  \
# 0      Donald Trump just couldn t wish all Americans ...           1
# 1      House Intelligence Committee Chairman Devin Nu...           1
# 2      On Friday, it was revealed that former Milwauk...           1
# 3      On Christmas day, Donald Trump announced that ...           1
# 4      Pope Francis used his annual Christmas Day mes...           1
# ...                                                  ...         ...
# 65693  Rapper T. I. unloaded on black celebrities who...           0
# 65694  When the Green Bay Packers lost to the Washing...           0
# 65695  The Macy’s of today grew from the union of sev...           0
# 65696  NATO, Russia To Hold Parallel Exercises In Bal...           1
# 65697    David Swanson is an author, activist, journa...           1
#
#                                           author
# 0                                        Unknown
# 1                                        Unknown
# 2                                        Unknown
# 3                                        Unknown
# 4                                        Unknown
# ...                                          ...
# 65693                              Jerome Hudson
# 65694                           Benjamin Hoffman
# 65695  Michael J. de la Merced and Rachel Abrams
# 65696                                Alex Ansary
# 65697                              David Swanson
#
# [65698 rows x 4 columns]

# %%
merged_df.to_csv("../dataset/processed/final_datasets.csv", index=False)

# %%
final_df = pd.read_csv("../dataset/processed/final_datasets.csv")
final_df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 65693  Rapper T.I.: Trump a ’Poster Child For White S...
# 65694  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 65695  Macy’s Is Said to Receive Takeover Approach by...
# 65696  NATO, Russia To Hold Parallel Exercises In Bal...
# 65697                          What Keeps the F-35 Alive
#
#                                                     text  unreliable  \
# 0      Donald Trump just couldn t wish all Americans ...           1
# 1      House Intelligence Committee Chairman Devin Nu...           1
# 2      On Friday, it was revealed that former Milwauk...           1
# 3      On Christmas day, Donald Trump announced that ...           1
# 4      Pope Francis used his annual Christmas Day mes...           1
# ...                                                  ...         ...
# 65693  Rapper T. I. unloaded on black celebrities who...           0
# 65694  When the Green Bay Packers lost to the Washing...           0
# 65695  The Macy’s of today grew from the union of sev...           0
# 65696  NATO, Russia To Hold Parallel Exercises In Bal...           1
# 65697    David Swanson is an author, activist, journa...           1
#
#                                           author
# 0                                        Unknown
# 1                                        Unknown
# 2                                        Unknown
# 3                                        Unknown
# 4                                        Unknown
# ...                                          ...
# 65693                              Jerome Hudson
# 65694                           Benjamin Hoffman
# 65695  Michael J. de la Merced and Rachel Abrams
# 65696                                Alex Ansary
# 65697                              David Swanson
#
# [65698 rows x 4 columns]

# %% [markdown]
# Thus, Merging of datasets is complete
